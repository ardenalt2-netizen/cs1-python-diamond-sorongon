# %% [markdown]
# <a href="https://colab.research.google.com/github/ardenalt2-netizen/cs1-python-diamond-sorongon/blob/main/python%20project%20the%20first.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Veni, Vidi, Dici.")
# Out:
# Veni, Vidi, Dici.
